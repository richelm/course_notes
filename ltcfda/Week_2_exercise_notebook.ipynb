# %% [markdown]
# # Exercise notebook 2: Cleaning up our act
# This Jupyter notebook, for Week 2 of The Open University's [Learn to code for Data Analysis](https://www.futurelearn.com/courses/learn-to-code/) course, has code examples and coding activities for you. Remember to run the code in this notebook before you start.
#
# You'll come across steps in the FutureLearn course directing you to this notebook. Once you've done the exercise, go back to FutureLearn to discuss it with your fellow learners and course facilitators and mark it as complete.

# %%
from pandas import *

# %% [markdown]
# ##Exercise 1: Dataframes and CSV files
#
# To read a CSV file into a dataframe you need to call the pandas function called <code>read_csv()</code>. The simplest usage of this function is with a single argument, a string that holds the name of the CSV file, for example.

# %%
df = read_csv('WHO POP TB all.csv')

# %% [markdown]
# ###Dataframe attributes
#
# An dataframe attribute is like a variable that can only be accessed in the context of a dataframe. Once such attribute is <code>columns</code> which holds a dataframe's column names.

# %%
df.columns
# Out:
# Index(['Country', 'Population (1000s)', 'TB deaths'], dtype='object')

# %% [markdown]
# ###Dataframe rows
# A dataframe has a default integer index for its rows, which starts at zero <code>0</code>. The `irow()` method returns the row at the given index.

# %%
df.irow(0) # first row, index 0
# Out:
# Country               Afghanistan
# Population (1000s)          30552
# TB deaths                   13000
# Name: 0, dtype: object

# %%
df.irow(2) # third row, index 2
# Out:
# Country               Algeria
# Population (1000s)      39208
# TB deaths                5100
# Name: 2, dtype: object

# %% [markdown]
# ###The <code>head()</code> method
#
# The `head()` method returns a dataframe with the first rows, as many as given in the argument. By default, if the argument is missing, it returns the first five rows.

# %%
df.head() # first five rows
# Out:
#        Country  Population (1000s)  TB deaths
# 0  Afghanistan               30552   13000.00
# 1      Albania                3173      20.00
# 2      Algeria               39208    5100.00
# 3      Andorra                  79       0.26
# 4       Angola               21472    6900.00

# %%
df.head(7) # first seven rows
# Out:
#                Country  Population (1000s)  TB deaths
# 0          Afghanistan               30552   13000.00
# 1              Albania                3173      20.00
# 2              Algeria               39208    5100.00
# 3              Andorra                  79       0.26
# 4               Angola               21472    6900.00
# 5  Antigua and Barbuda                  90       1.20
# 6            Argentina               41446     570.00

# %% [markdown]
# ###The <code>tail()</code> method
# The <code>tail()</code> method is similar to the <code>head()</code> method. If no argument is used, the last five rows of the dataframe are returned, otherwise the number of rows returned is dependent on the argument.

# %%
df.tail() # last five rows
# Out:
#                                 Country  Population (1000s)  TB deaths
# 189  Venezuela (Bolivarian Republic of)               30405        480
# 190                            Viet Nam               91680      17000
# 191                               Yemen               24407        990
# 192                              Zambia               14539       3600
# 193                            Zimbabwe               14150       5700

# %% [markdown]
# ###Selecting and displaying columns in a dataframe
# You found in Week 1 that you can select and display the values for a single dataframe column by puting the name of the column (in quotes) within square brackets immediately after the dataframe's name. However you can also select and display the values for multiple columns too.
#
# To get multiple columns you need to use a list. A list in Python is a number of items separated by commas within square brackets, for example `['Country', 'Population (1000s)']`. This list is then put within square brackets immediately after the dataframe's name. The resulting expression represents a new dataframe, just with those columns, and therefore any dataframe method can be applied to it, like for example `head()`:

# %%
df[['Country', 'Population (1000s)']].head()
# Out:
#        Country  Population (1000s)
# 0  Afghanistan               30552
# 1      Albania                3173
# 2      Algeria               39208
# 3      Andorra                  79
# 4       Angola               21472

# %% [markdown]
# ###Applying methods to a dataframe column
# The `irow()`, <code>head()</code> and <code>tail()</code> methods discussed above can be used with single columns.

# %%
df['TB deaths'].irow(2) # third value of deaths column
# Out:
# 5100.0

# %%
df['Population (1000s)'].tail() # last five values of population column
# Out:
# 189    30405
# 190    91680
# 191    24407
# 192    14539
# 193    14150
# Name: Population (1000s), dtype: int64

# %% [markdown]
# ###Tasks
#
# In the code cell below, write the code to get and display the 55th row in the dataframe <code>df</code>.

# %%
df.irow(54)
# Out:
# Country               El Salvador
# Population (1000s)           6340
# TB deaths                      61
# Name: 54, dtype: object

# %% [markdown]
# In the code cell below write the code to display the first 10 rows of the dataframe <code>df</code>.

# %%
df.head(10)
# Out:
#                Country  Population (1000s)  TB deaths
# 0          Afghanistan               30552   13000.00
# 1              Albania                3173      20.00
# 2              Algeria               39208    5100.00
# 3              Andorra                  79       0.26
# 4               Angola               21472    6900.00
# 5  Antigua and Barbuda                  90       1.20
# 6            Argentina               41446     570.00
# 7              Armenia                2977     170.00
# 8            Australia               23343      45.00
# 9              Austria                8495      29.00

# %% [markdown]
# In the code cell below, select and display the first eight rows from the <code>'Country'</code> and <code>'TB deaths'</code> columns.

# %%
df[['Country','TB deaths']].head(8)
# Out:
#                Country  TB deaths
# 0          Afghanistan   13000.00
# 1              Albania      20.00
# 2              Algeria    5100.00
# 3              Andorra       0.26
# 4               Angola    6900.00
# 5  Antigua and Barbuda       1.20
# 6            Argentina     570.00
# 7              Armenia     170.00

# %% [markdown]
# **Now go back to the Exercise 1 step in FutureLearn to discuss and mark it complete.**

# %% [markdown]
# ##Exercise 2: Comparison operators
# Python has the following comparison operators:
#
#     == (equals)
#     != (not equal)
#     < (less than)
#     > (greater than)
#     <= (less than or equal to)
#     >= (greater than or equal to)
#
# The following code will get and display all the rows in `df` where it is `True` that the value in the `'Population (1000s)'` column is greater than `80000`.

# %%
df[df['Population (1000s)'] > 80000]
# Out:
#                       Country  Population (1000s)  TB deaths
# 13                 Bangladesh              156595      80000
# 23                     Brazil              200362       4400
# 36                      China             1393337      41000
# 53                      Egypt               82056        550
# 58                   Ethiopia               94101      30000
# 65                    Germany               82727        300
# 77                      India             1252140     240000
# 78                  Indonesia              249866      64000
# 85                      Japan              127144       2100
# 109                    Mexico              122332       2200
# 124                   Nigeria              173615     160000
# 128                  Pakistan              182143      49000
# 134               Philippines               98394      27000
# 141        Russian Federation              142834      17000
# 185  United States of America              320051        490
# 190                  Viet Nam               91680      17000

# %% [markdown]
# ### Task
# In the code cell below write code to find all the rows in <code>df</code> where TB deaths exceed 10000.

# %%
df[df['TB deaths'] > 10000]
# Out:
#                               Country  Population (1000s)  TB deaths
# 0                         Afghanistan               30552      13000
# 13                         Bangladesh              156595      80000
# 36                              China             1393337      41000
# 47   Democratic Republic of the Congo               67514      46000
# 58                           Ethiopia               94101      30000
# 77                              India             1252140     240000
# 78                          Indonesia              249866      64000
# 100                        Madagascar               22925      12000
# 115                        Mozambique               25834      18000
# 116                           Myanmar               53259      26000
# 124                           Nigeria              173615     160000
# 128                          Pakistan              182143      49000
# 134                       Philippines               98394      27000
# 141                Russian Federation              142834      17000
# 159                      South Africa               52776      25000
# 190                          Viet Nam               91680      17000

# %% [markdown]
# **Now go back to the Exercise 2 step in FutureLearn to discuss and mark it complete.**

# %% [markdown]
# ##Exercise 3: Bitwise operators
#
# Pandas has two operators to make more complicated queries. Use the operator `&` (means 'and') to select rows where two conditions are both true. Use the operator `|` (means 'or') to select rows where at least one condition is true. Don't forget to put parentheses around _each_ comparison. For example, the following expression selects only countries with a population over 80 million inhabitants **and** with more that 10 thousand deaths.

# %%
df[(df['Population (1000s)'] > 80000) & (df['TB deaths'] > 10000)]
# Out:
#                 Country  Population (1000s)  TB deaths
# 13           Bangladesh              156595      80000
# 36                China             1393337      41000
# 58             Ethiopia               94101      30000
# 77                India             1252140     240000
# 78            Indonesia              249866      64000
# 124             Nigeria              173615     160000
# 128            Pakistan              182143      49000
# 134         Philippines               98394      27000
# 141  Russian Federation              142834      17000
# 190            Viet Nam               91680      17000

# %% [markdown]
# If the same columns will be used repeatedly in the program, the code becomes more readable if written as follows:

# %%
population = df['Population (1000s)']
deaths = df['TB deaths']
df[(population > 80000) & (deaths > 10000)]
# Out:
#                 Country  Population (1000s)  TB deaths
# 13           Bangladesh              156595      80000
# 36                China             1393337      41000
# 58             Ethiopia               94101      30000
# 77                India             1252140     240000
# 78            Indonesia              249866      64000
# 124             Nigeria              173615     160000
# 128            Pakistan              182143      49000
# 134         Philippines               98394      27000
# 141  Russian Federation              142834      17000
# 190            Viet Nam               91680      17000

# %% [markdown]
# ###Task
# In the code cell below find  all the countries where the Population (1000s) is **less than or equal to** 50000 **or** TB deaths are **greater than or equal to** 20000.

# %%
population = df['Population (1000s)']
deaths = df['TB deaths']
df[(population <= 50000) | (deaths >= 20000)]
# Out:
#                                        Country  Population (1000s)  TB deaths
# 0                                  Afghanistan               30552   13000.00
# 1                                      Albania                3173      20.00
# 2                                      Algeria               39208    5100.00
# 3                                      Andorra                  79       0.26
# 4                                       Angola               21472    6900.00
# 5                          Antigua and Barbuda                  90       1.20
# 6                                    Argentina               41446     570.00
# 7                                      Armenia                2977     170.00
# 8                                    Australia               23343      45.00
# 9                                      Austria                8495      29.00
# 10                                  Azerbaijan                9413     360.00
# 11                                     Bahamas                 377       1.80
# 12                                     Bahrain                1332       9.60
# 13                                  Bangladesh              156595   80000.00
# 14                                    Barbados                 285       2.00
# 15                                     Belarus                9357     850.00
# 16                                     Belgium               11104      18.00
# 17                                      Belize                 332      20.00
# 18                                       Benin               10323    1300.00
# 19                                      Bhutan                 754      88.00
# 20            Bolivia (Plurinational State of)               10671     430.00
# 21                      Bosnia and Herzegovina                3829     190.00
# 22                                    Botswana                2021     440.00
# 24                           Brunei Darussalam                 418      13.00
# 25                                    Bulgaria                7223     150.00
# 26                                Burkina Faso               16935    1500.00
# 27                                     Burundi               10163    2300.00
# 28                               Côte d'Ivoire               20316    4000.00
# 29                                  Cabo Verde                 499     150.00
# 30                                    Cambodia               15135   10000.00
# ..                                         ...                 ...        ...
# 159                               South Africa               52776   25000.00
# 160                                South Sudan               11296    4500.00
# 161                                      Spain               46927     240.00
# 162                                  Sri Lanka               21273    1300.00
# 163                                      Sudan               37964    9700.00
# 164                                   Suriname                 539      12.00
# 165                                  Swaziland                1250    1100.00
# 166                                     Sweden                9571      13.00
# 167                                Switzerland                8078      17.00
# 168                       Syrian Arab Republic               21898     450.00
# 169                                 Tajikistan                8208     570.00
# 171  The former Yugoslav republic of Macedonia                2107      33.00
# 172                                Timor-Leste                1133     990.00
# 173                                       Togo                6817     810.00
# 174                                      Tonga                 105       2.50
# 175                        Trinidad and Tobago                1341      29.00
# 176                                    Tunisia               10997     230.00
# 178                               Turkmenistan                5240    1300.00
# 179                                     Tuvalu                  10       2.80
# 180                                     Uganda               37579    4100.00
# 181                                    Ukraine               45239    6600.00
# 182                       United Arab Emirates                9346      64.00
# 184                United Republic of Tanzania               49253    6000.00
# 186                                    Uruguay                3407      40.00
# 187                                 Uzbekistan               28934    2200.00
# 188                                    Vanuatu                 253      16.00
# 189         Venezuela (Bolivarian Republic of)               30405     480.00
# 191                                      Yemen               24407     990.00
# 192                                     Zambia               14539    3600.00
# 193                                   Zimbabwe               14150    5700.00
#
# [180 rows x 3 columns]

# %% [markdown]
# **Now go back to the Exercise 3 step in FutureLearn to discuss and mark it complete.**

# %% [markdown]
# ##Exercise 4: Display rows from dataframe
#
# The 2014 Weather Underground data for London has been downloaded from the site as a CSV file and can now be read into a dataframe.

# %%
london = read_csv('London_2014.csv')
london.head()
# Out:
#         GMT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  2014-1-1                52                 47                42
# 1  2014-1-2                52                 48                43
# 2  2014-1-3                51                 47                43
# 3  2014-1-4                49                 43                37
# 4  2014-1-5                54                 44                33
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0              48              44             39            94
# 1              48              43             40            94
# 2              49              41             35            94
# 3              46              42             36            93
# 4              52              40             31           100
#
#     Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 0              86             73       ...                           19
# 1              81             60       ...                           19
# 2              76             54       ...                           19
# 3              85             65       ...                           19
# 4              88             77       ...                           19
#
#     Mean VisibilityMiles   Min VisibilityMiles   Max Wind SpeedMPH  \
# 0                      7                     1                  25
# 1                     10                     3                  20
# 2                      8                     0                  31
# 3                      8                     3                  22
# 4                      9                     3                  22
#
#     Mean Wind SpeedMPH   Max Gust SpeedMPH  PrecipitationIn   CloudCover  \
# 0                   16                  41             0.39            4
# 1                   13                  31             0.04            2
# 2                   18                  43             0.28            2
# 3                   13                  24             0.39            4
# 4                   10                 NaN             0.01            5
#
#               Events   WindDirDegrees
# 0               Rain              186
# 1               Rain              214
# 2  Rain-Thunderstorm              219
# 3               Rain              211
# 4               Rain              199
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Removing initial spaces
#
# There are too many columns for the dataframe to fit horizontally in this notebook, but they can be displayed separately.

# %%
london.columns
# Out:
# Index(['GMT', 'Max TemperatureF', 'Mean TemperatureF', 'Min TemperatureF',
#        'Max Dew PointF', 'MeanDew PointF', 'Min DewpointF', 'Max Humidity',
#        ' Mean Humidity', ' Min Humidity', ' Max Sea Level PressureIn',
#        ' Mean Sea Level PressureIn', ' Min Sea Level PressureIn',
#        ' Max VisibilityMiles', ' Mean VisibilityMiles', ' Min VisibilityMiles',
#        ' Max Wind SpeedMPH', ' Mean Wind SpeedMPH', ' Max Gust SpeedMPH',
#        'PrecipitationIn', ' CloudCover', ' Events', ' WindDirDegrees'],
#       dtype='object')

# %% [markdown]
# This shows that <code>' Max Wind SpeedKm/h'</code> is prefixed by a space, as do other columm names such as <code>' Mean Humidity'</code> and <code>' Max Sea Level PressurehPa'</code>.
#
# The  <code>read_csv()</code> function has interpreted spaces after commas as being part of the next value. This can be rectified  easily by adding another argument to the <code>read_csv()</code> function to skiop the initial spaces after a comma.

# %%
london = read_csv('London_2014.csv', skipinitialspace=True)

# %% [markdown]
# ### Removing extra characters
#
# Another problem shown above is that the final column is called <code>'WindDirDegrees&lt; br /&gt;'</code>.
#
# When the dataset was exported from the Weather Underground web site html line breaks were automatically added to each line in the file which <code>read_csv()</code> has interpreted as part of the column name and its values. This can be seen more clearly by looking at more values in the final column:

# %%
# i didn't have this problem because I cut and pasted.
#london['WindDirDegrees<br />'].head()
london['WindDirDegrees'].head()
# Out:
# 0    186
# 1    214
# 2    219
# 3    211
# 4    199
# Name: WindDirDegrees, dtype: int64

# %% [markdown]
# <code>'WindDirDegrees&lt; br /&gt;'</code> can be changed to <code>'WindDirDegrees'</code> with the <code>rename()</code> method as follows:

# %%
london = london.rename(columns={'WindDirDegrees<br />' : 'WindDirDegrees'})

# %% [markdown]
# To remove the <code>'&lt; br /&gt;'</code> html line breaks from the values in the <code>'WindDirDegrees'</code> column you need to use the string method <code>rstrip()</code> which is used to remove characters from the *end* or 'rear' of a string:

# %%
#london['WindDirDegrees'] = london['WindDirDegrees'].str.rstrip('<br />')

# %% [markdown]
# Display the first few rows of the <code>'WindDirDegrees'</code> to confirm the change:

# %%
london['WindDirDegrees'].head()
# Out:
# 0    186
# 1    214
# 2    219
# 3    211
# 4    199
# Name: WindDirDegrees, dtype: int64

# %% [markdown]
# ### Missing values
#
# Missing (also called null or not available) values are marked as NaN (not a number) in dataframes.

# %%
london['Events'].tail()
# Out:
# 360    Rain
# 361     NaN
# 362     NaN
# 363     NaN
# 364     Fog
# Name: Events, dtype: object

# %% [markdown]
# The `isnull()` method returns `True` for each row in a column that has a null value. The method can be used to select and display those rows. Scroll the table below to the right to check that the events column is only showing missing values.

# %%
london[london['Events'].isnull()]
# Out:
#             GMT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 32     2014-2-2                50                 46                41
# 33     2014-2-3                47                 42                38
# 43    2014-2-13                47                 42                38
# 52    2014-2-22                53                 46                40
# 63     2014-3-5                55                 44                32
# 64     2014-3-6                56                 48                41
# 66     2014-3-8                60                 52                44
# 67     2014-3-9                66                 54                42
# 68    2014-3-10                55                 47                39
# 70    2014-3-12                61                 48                35
# 73    2014-3-15                64                 54                44
# 74    2014-3-16                66                 55                44
# 75    2014-3-17                57                 49                41
# 77    2014-3-19                61                 52                44
# 87    2014-3-29                66                 56                46
# 92     2014-4-3                64                 58                51
# 93     2014-4-4                59                 54                48
# 98     2014-4-9                62                 50                39
# 99    2014-4-10                61                 52                43
# 100   2014-4-11                60                 54                49
# 101   2014-4-12                57                 50                43
# 102   2014-4-13                61                 54                46
# 103   2014-4-14                60                 51                42
# 104   2014-4-15                58                 48                38
# 105   2014-4-16                62                 50                38
# 106   2014-4-17                62                 52                42
# 107   2014-4-18                54                 48                42
# 108   2014-4-19                57                 48                38
# 122    2014-5-3                58                 47                36
# 123    2014-5-4                61                 50                40
# ..          ...               ...                ...               ...
# 252   2014-9-10                70                 61                52
# 253   2014-9-11                65                 58                50
# 254   2014-9-12                74                 64                55
# 255   2014-9-13                70                 62                54
# 257   2014-9-15                71                 62                53
# 258   2014-9-16                74                 64                55
# 259   2014-9-17                69                 64                60
# 260   2014-9-18                78                 68                58
# 264   2014-9-22                66                 56                45
# 267   2014-9-25                67                 56                44
# 269   2014-9-27                70                 62                54
# 270   2014-9-28                76                 67                58
# 272   2014-9-30                72                 64                57
# 274   2014-10-2                72                 66                57
# 292  2014-10-20                63                 58                53
# 295  2014-10-23                61                 56                51
# 297  2014-10-25                61                 52                44
# 298  2014-10-26                60                 56                53
# 299  2014-10-27                65                 60                53
# 302  2014-10-30                64                 60                55
# 303  2014-10-31                73                 63                53
# 322  2014-11-19                52                 48                44
# 323  2014-11-20                52                 47                42
# 339   2014-12-6                43                 36                30
# 346  2014-12-13                44                 38                32
# 351  2014-12-18                56                 54                52
# 358  2014-12-25                47                 42                35
# 361  2014-12-28                43                 36                28
# 362  2014-12-29                42                 34                25
# 363  2014-12-30                42                 33                24
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 32               40              37             34            93
# 33               41              38             35            93
# 43               36              33             30            81
# 52               41              37             33            87
# 63               39              36             30           100
# 64               45              41             38            93
# 66               45              40             35            93
# 67               45              40             37            81
# 68               46              40             36            87
# 70               46              40             34            93
# 73               43              41             36            87
# 74               46              43             38            87
# 75               45              42             39            93
# 77               45              41             39            93
# 87               45              40             30            93
# 92               52              49             48            88
# 93               50              46             42            88
# 98               45              42             37            93
# 99               43              41             37            93
# 100              41              39             35            71
# 101              45              41             37            87
# 102              46              41             35            93
# 103              41              37             32            87
# 104              39              35             32            81
# 105              40              34             21            87
# 106              45              40             33            81
# 107              41              35             31            81
# 108              39              35             32            81
# 122              37              33             31            87
# 123              43              40             36            87
# ..              ...             ...            ...           ...
# 252              54              50             47            94
# 253              52              50             47            94
# 254              57              53             49            94
# 255              57              54             51           100
# 257              57              53             49           100
# 258              61              57             52           100
# 259              59              57             55            94
# 260              61              59             56            94
# 264              48              46             42           100
# 267              54              49             41            93
# 269              57              54             51            94
# 270              59              57             55            94
# 272              59              56             53            94
# 274              57              56             52            94
# 292              52              51             48            88
# 295              57              50             45            94
# 297              48              46             43           100
# 298              48              47             44            77
# 299              55              53             48            94
# 302              59              57             53           100
# 303              59              55             52           100
# 322              48              45             41           100
# 323              46              43             41            93
# 339              37              33             30           100
# 346              36              33             30           100
# 351              52              51             50            94
# 358              37              36             34            93
# 361              34              29             27           100
# 362              36              31             24           100
# 363              36              31             25           100
#
#      Mean Humidity  Min Humidity       ...        Max VisibilityMiles  \
# 32              71            43       ...                         19
# 33              79            55       ...                         19
# 43              66            45       ...                         19
# 52              68            38       ...                         19
# 63              72            40       ...                         19
# 64              77            50       ...                         19
# 66              65            29       ...                         19
# 67              58            28       ...                         16
# 68              73            57       ...                         19
# 70              76            40       ...                         12
# 73              64            24       ...                         19
# 74              63            28       ...                         19
# 75              74            47       ...                         19
# 77              68            35       ...                         19
# 87              57            18       ...                         19
# 92              75            52       ...                         13
# 93              71            46       ...                         19
# 98              68            38       ...                         19
# 99              62            31       ...                         19
# 100             53            28       ...                         19
# 101             66            42       ...                         19
# 102             63            33       ...                         19
# 103             57            25       ...                         19
# 104             58            26       ...                         19
# 105             54            15       ...                         19
# 106             59            27       ...                         19
# 107             57            28       ...                         19
# 108             59            33       ...                         19
# 122             56            26       ...                         19
# 123             62            32       ...                         19
# ..             ...           ...       ...                        ...
# 252             68            38       ...                         14
# 253             70            45       ...                          8
# 254             70            33       ...                         19
# 255             75            45       ...                         19
# 257             74            35       ...                         16
# 258             77            39       ...                         12
# 259             78            59       ...                          7
# 260             74            43       ...                         12
# 264             68            35       ...                         12
# 267             71            48       ...                         19
# 269             71            43       ...                         19
# 270             72            41       ...                         17
# 272             78            44       ...                         17
# 274             75            46       ...                         19
# 292             76            50       ...                         19
# 295             76            58       ...                         19
# 297             75            41       ...                         19
# 298             67            45       ...                         19
# 299             80            55       ...                         19
# 302             89            72       ...                          8
# 303             78            40       ...                         19
# 322             88            70       ...                          6
# 323             87            66       ...                          8
# 339             85            60       ...                         19
# 346             83            53       ...                         19
# 351             85            74       ...                         19
# 358             79            51       ...                         19
# 361             76            45       ...                         19
# 362             87            62       ...                         15
# 363             90            68       ...                         17
#
#      Mean VisibilityMiles  Min VisibilityMiles  Max Wind SpeedMPH  \
# 32                     10                    6                 23
# 33                     10                    6                 20
# 43                      9                    6                 26
# 52                     10                    6                 18
# 63                      9                    5                 13
# 64                      9                    4                 20
# 66                      7                    4                 17
# 67                      6                    3                 15
# 68                      8                    4                 14
# 70                      5                    2                  7
# 73                     11                    3                 17
# 74                     12                    4                 15
# 75                      8                    3                 13
# 77                     11                    5                 16
# 87                      6                    2                 21
# 92                      4                    2                 16
# 93                      7                    1                 15
# 98                      9                    4                 14
# 99                      9                    6                 12
# 100                    11                    6                  8
# 101                    10                    6                 18
# 102                     8                    6                 16
# 103                    10                    6                 13
# 104                    13                    6                 13
# 105                    13                    6                 10
# 106                    10                    6                 13
# 107                     9                    6                 12
# 108                     9                    6                 14
# 122                    10                    6                  9
# 123                    10                    6                 12
# ..                    ...                  ...                ...
# 252                     8                    6                 13
# 253                     5                    3                  7
# 254                     7                    3                 12
# 255                     7                    2                 12
# 257                     7                    3                  9
# 258                     4                    1                 12
# 259                     4                    2                 12
# 260                     4                    1                 12
# 264                     6                    4                  7
# 267                    10                    6                 16
# 269                     9                    6                  8
# 270                     8                    4                 10
# 272                     6                    2                 12
# 274                     9                    4                 13
# 292                     9                    6                 17
# 295                     9                    6                 14
# 297                     8                    6                 16
# 298                     8                    6                 17
# 299                     8                    5                 18
# 302                     4                    1                 10
# 303                     8                    2                 14
# 322                     3                    2                  9
# 323                     4                    2                 10
# 339                     9                    6                  9
# 346                    12                    6                  8
# 351                     8                    6                 23
# 358                    12                    6                 15
# 361                    10                    5                 10
# 362                     6                    3                  8
# 363                     5                    2                  9
#
#      Mean Wind SpeedMPH  Max Gust SpeedMPH  PrecipitationIn  CloudCover  \
# 32                   15                 29             0.00           2
# 33                   11                NaN             0.00           4
# 43                   17                 30             0.00           2
# 52                   13                NaN             0.00           2
# 63                    4                NaN             0.01           1
# 64                    9                 26             0.00           2
# 66                   11                NaN             0.00           6
# 67                    6                 21             0.00         NaN
# 68                    5                NaN             0.00           6
# 70                    5                NaN             0.00           4
# 73                   10                NaN             0.00           1
# 74                   10                NaN             0.00         NaN
# 75                    9                NaN             0.00           3
# 77                   11                NaN             0.00           2
# 87                   10                NaN             0.00         NaN
# 92                    7                NaN             0.00           5
# 93                    9                NaN             0.00           5
# 98                    8                NaN             0.00           2
# 99                    6                NaN             0.00           3
# 100                   5                NaN             0.00           1
# 101                   7                NaN             0.00           1
# 102                   9                NaN             0.00           2
# 103                   8                NaN             0.00           1
# 104                   6                NaN             0.00           1
# 105                   7                NaN             0.00           1
# 106                   7                NaN             0.00           2
# 107                   8                NaN             0.00           3
# 108                   7                NaN             0.00           4
# 122                   5                NaN             0.00           1
# 123                   6                 25             0.00           1
# ..                  ...                ...              ...         ...
# 252                   5                NaN             0.00           2
# 253                   4                NaN             0.00           6
# 254                   7                NaN             0.00           3
# 255                   7                NaN             0.00           4
# 257                   4                NaN             0.00           3
# 258                   5                NaN             0.00           5
# 259                   8                NaN             0.00           5
# 260                   7                 22             0.00           5
# 264                   4                NaN             0.01           1
# 267                   8                NaN             0.00           5
# 269                   3                NaN             0.00           6
# 270                   4                NaN             0.00           4
# 272                   8                 20             0.00           4
# 274                   5                 22             0.00           3
# 292                  12                NaN             0.01           3
# 295                  10                NaN             0.00           5
# 297                   8                NaN             0.00           4
# 298                  11                 25             0.00           5
# 299                  10                 25             0.00           3
# 302                   6                NaN             0.00           5
# 303                   5                 30             0.00           1
# 322                   6                NaN             0.00           2
# 323                   5                NaN             0.00           3
# 339                   5                NaN             0.01           4
# 346                   5                NaN             0.00           2
# 351                  18                 37             0.00           6
# 358                  10                NaN             0.00           1
# 361                   7                NaN             0.00           1
# 362                   5                NaN             0.01           1
# 363                   4                NaN             0.01           3
#
#      Events  WindDirDegrees
# 32      NaN             216
# 33      NaN             133
# 43      NaN             236
# 52      NaN             228
# 63      NaN             248
# 64      NaN             206
# 66      NaN             156
# 67      NaN             170
# 68      NaN              27
# 70      NaN              31
# 73      NaN             277
# 74      NaN             266
# 75      NaN             263
# 77      NaN             241
# 87      NaN              99
# 92      NaN              96
# 93      NaN             253
# 98      NaN             261
# 99      NaN             278
# 100     NaN             351
# 101     NaN             262
# 102     NaN             283
# 103     NaN             330
# 104     NaN              64
# 105     NaN             139
# 106     NaN             279
# 107     NaN              21
# 108     NaN              56
# 122     NaN              39
# 123     NaN             196
# ..      ...             ...
# 252     NaN              92
# 253     NaN              42
# 254     NaN              76
# 255     NaN              56
# 257     NaN              71
# 258     NaN              70
# 259     NaN              58
# 260     NaN              71
# 264     NaN             309
# 267     NaN             249
# 269     NaN             146
# 270     NaN             116
# 272     NaN             222
# 274     NaN             203
# 292     NaN             238
# 295     NaN             214
# 297     NaN             237
# 298     NaN             217
# 299     NaN             192
# 302     NaN             170
# 303     NaN             170
# 322     NaN              93
# 323     NaN              69
# 339     NaN             265
# 346     NaN             278
# 351     NaN             245
# 358     NaN             275
# 361     NaN               5
# 362     NaN             289
# 363     NaN             258
#
# [114 rows x 23 columns]

# %% [markdown]
# One way to deal with missing values is to replace them by some value. The column method `fillna()` fills all not available value cells with the value given as argument. In the example below, each missing event is replaced by the empty string.

# %%
london['Events'] = london['Events'].fillna('')
london[london['Events'].isnull()]
# Out:
# Empty DataFrame
# Columns: [GMT, Max TemperatureF, Mean TemperatureF, Min TemperatureF, Max Dew PointF, MeanDew PointF, Min DewpointF, Max Humidity, Mean Humidity, Min Humidity, Max Sea Level PressureIn, Mean Sea Level PressureIn, Min Sea Level PressureIn, Max VisibilityMiles, Mean VisibilityMiles, Min VisibilityMiles, Max Wind SpeedMPH, Mean Wind SpeedMPH, Max Gust SpeedMPH, PrecipitationIn, CloudCover, Events, WindDirDegrees]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# The empty dataframe (no rows) confirms there are no more missing event values.
#
# Another way to deal with missing values is to ignore rows with them. The `dropna()` dataframe method returns a new dataframe where all rows with at least one non-available value have been removed.

# %%
london.dropna()
# Out:
#             GMT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0      2014-1-1                52                 47                42
# 1      2014-1-2                52                 48                43
# 2      2014-1-3                51                 47                43
# 3      2014-1-4                49                 43                37
# 5      2014-1-6                54                 50                47
# 6      2014-1-7                53                 50                46
# 7      2014-1-8                53                 48                44
# 8      2014-1-9                51                 46                41
# 9     2014-1-10                51                 44                36
# 15    2014-1-16                51                 46                42
# 16    2014-1-17                48                 44                41
# 21    2014-1-22                51                 46                42
# 22    2014-1-23                47                 42                36
# 24    2014-1-25                54                 48                41
# 25    2014-1-26                49                 42                36
# 26    2014-1-27                47                 41                35
# 30    2014-1-31                49                 41                33
# 31     2014-2-1                48                 44                41
# 32     2014-2-2                50                 46                41
# 34     2014-2-4                48                 44                39
# 35     2014-2-5                50                 46                41
# 36     2014-2-6                50                 46                42
# 37     2014-2-7                49                 44                39
# 38     2014-2-8                49                 46                44
# 39     2014-2-9                47                 44                40
# 41    2014-2-11                47                 41                35
# 42    2014-2-12                48                 42                36
# 43    2014-2-13                47                 42                38
# 44    2014-2-14                54                 46                37
# 45    2014-2-15                51                 46                41
# ..          ...               ...                ...               ...
# 281   2014-10-9                64                 58                52
# 282  2014-10-10                65                 56                48
# 284  2014-10-12                58                 50                43
# 288  2014-10-16                64                 58                52
# 289  2014-10-17                67                 61                55
# 291  2014-10-19                69                 63                57
# 293  2014-10-21                57                 52                46
# 298  2014-10-26                60                 56                53
# 299  2014-10-27                65                 60                53
# 300  2014-10-28                65                 57                49
# 303  2014-10-31                73                 63                53
# 304   2014-11-1                64                 60                55
# 305   2014-11-2                60                 55                50
# 306   2014-11-3                50                 46                42
# 310   2014-11-7                55                 50                46
# 311   2014-11-8                58                 52                45
# 312   2014-11-9                55                 50                42
# 336   2014-12-3                47                 43                39
# 342   2014-12-9                53                 42                31
# 345  2014-12-12                48                 42                35
# 347  2014-12-14                50                 40                30
# 350  2014-12-17                55                 48                40
# 351  2014-12-18                56                 54                52
# 353  2014-12-20                49                 44                39
# 354  2014-12-21                54                 46                38
# 355  2014-12-22                56                 53                50
# 356  2014-12-23                55                 52                50
# 357  2014-12-24                53                 46                39
# 360  2014-12-27                40                 38                35
# 364  2014-12-31                46                 35                24
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0                48              44             39            94
# 1                48              43             40            94
# 2                49              41             35            94
# 3                46              42             36            93
# 5                52              46             43            94
# 6                46              45             43            87
# 7                51              45             42            94
# 8                52              41             36            94
# 9                45              40             35            93
# 15               48              43             40            94
# 16               44              42             39            93
# 21               45              43             40           100
# 22               43              37             32           100
# 24               47              42             32           100
# 25               47              37             32            93
# 26               39              36             31            87
# 30               47              39             34           100
# 31               48              38             32           100
# 32               40              37             34            93
# 34               40              38             34            87
# 35               45              40             36            93
# 36               48              42             37           100
# 37               48              40             32           100
# 38               46              39             32            93
# 39               38              34             28            81
# 41               43              35             30            93
# 42               43              36             30            93
# 43               36              33             30            81
# 44               50              40             32            94
# 45               41              38             36            87
# ..              ...             ...            ...           ...
# 281              52              50             46            88
# 282              54              50             46            94
# 284              52              47             41           100
# 288              57              54             52           100
# 289              59              57             54           100
# 291              61              56             51            94
# 293              55              43             33            94
# 298              48              47             44            77
# 299              55              53             48            94
# 300              57              53             48           100
# 303              59              55             52           100
# 304              59              51             43            94
# 305              55              52             46            94
# 306              48              44             40            94
# 310              54              47             41            95
# 311              52              47             41            94
# 312              48              44             40           100
# 336              41              37             34            93
# 342              51              38             30           100
# 345              48              40             31            94
# 347              48              38             30           100
# 350              52              50             43           100
# 351              52              51             50            94
# 353              39              38             36            87
# 354              49              43             37            93
# 355              52              48             44            94
# 356              48              45             41            82
# 357              50              39             29            94
# 360              46              34             31            93
# 364              41              35             25           100
#
#      Mean Humidity  Min Humidity       ...        Max VisibilityMiles  \
# 0               86            73       ...                         19
# 1               81            60       ...                         19
# 2               76            54       ...                         19
# 3               85            65       ...                         19
# 5               78            60       ...                         19
# 6               78            63       ...                         19
# 7               85            69       ...                         17
# 8               76            53       ...                         19
# 9               85            66       ...                         19
# 15              85            67       ...                         19
# 16              86            68       ...                         19
# 21              87            62       ...                         19
# 22              81            50       ...                         19
# 24              83            48       ...                         19
# 25              80            62       ...                         19
# 26              80            61       ...                         19
# 30              90            72       ...                         14
# 31              73            46       ...                         19
# 32              71            43       ...                         19
# 34              76            50       ...                         19
# 35              75            56       ...                         16
# 36              82            62       ...                         18
# 37              78            46       ...                         19
# 38              74            50       ...                         19
# 39              65            42       ...                         19
# 41              75            43       ...                         19
# 42              74            49       ...                         19
# 43              66            45       ...                         19
# 44              81            60       ...                         19
# 45              67            51       ...                         19
# ..             ...           ...       ...                        ...
# 281             77            48       ...                         19
# 282             80            45       ...                         19
# 284             84            57       ...                         19
# 288             87            58       ...                         19
# 289             84            62       ...                         18
# 291             78            48       ...                         19
# 293             65            37       ...                         19
# 298             67            45       ...                         19
# 299             80            55       ...                         19
# 300             83            47       ...                         19
# 303             78            40       ...                         19
# 304             74            39       ...                         18
# 305             82            64       ...                         18
# 306             84            60       ...                         19
# 310             80            52       ...                         19
# 311             84            64       ...                         19
# 312             83            47       ...                         19
# 336             78            56       ...                         19
# 342             86            64       ...                         19
# 345             79            59       ...                         19
# 347             84            62       ...                         19
# 350             90            76       ...                         19
# 351             85            74       ...                         19
# 353             75            53       ...                         19
# 354             80            65       ...                         19
# 355             77            63       ...                         19
# 356             72            58       ...                         19
# 357             71            38       ...                         19
# 360             83            64       ...                         19
# 364             89            70       ...                         12
#
#      Mean VisibilityMiles  Min VisibilityMiles  Max Wind SpeedMPH  \
# 0                       7                    1                 25
# 1                      10                    3                 20
# 2                       8                    0                 31
# 3                       8                    3                 22
# 5                       7                    3                 31
# 6                       8                    3                 24
# 7                       9                    4                 15
# 8                       8                    3                 25
# 9                      11                    6                 15
# 15                      8                    2                 17
# 16                      8                    3                 18
# 21                      8                    4                 14
# 22                      8                    3                 16
# 24                      6                    1                 25
# 25                      9                    2                 23
# 26                     10                    6                 21
# 30                      5                    0                 23
# 31                      8                    2                 31
# 32                     10                    6                 23
# 34                      9                    4                 24
# 35                      8                    4                 28
# 36                      8                    1                 22
# 37                      7                    2                 24
# 38                      8                    2                 28
# 39                      9                    6                 29
# 41                      9                    4                 25
# 42                      9                    3                 32
# 43                      9                    6                 26
# 44                      8                    3                 39
# 45                      9                    6                 41
# ..                    ...                  ...                ...
# 281                     9                    2                 24
# 282                    11                    6                 16
# 284                     9                    4                 14
# 288                     8                    4                 13
# 289                     9                    5                 15
# 291                     9                    3                 21
# 293                     9                    2                 29
# 298                     8                    6                 17
# 299                     8                    5                 18
# 300                     8                    0                 15
# 303                     8                    2                 14
# 304                     8                    6                 20
# 305                     9                    0                 17
# 306                     9                    1                 14
# 310                     7                    1                 26
# 311                     9                    3                 21
# 312                     7                    0                  9
# 336                     9                    6                 14
# 342                     9                    2                 23
# 345                     7                    2                 25
# 347                    10                    6                 18
# 350                     8                    4                 21
# 351                     8                    6                 23
# 353                     9                    6                 20
# 354                     7                    6                 22
# 355                     9                    5                 25
# 356                     7                    6                 26
# 357                     8                    6                 21
# 360                     8                    6                 26
# 364                     5                    0                 14
#
#      Mean Wind SpeedMPH  Max Gust SpeedMPH  PrecipitationIn  CloudCover  \
# 0                    16                 41             0.39           4
# 1                    13                 31             0.04           2
# 2                    18                 43             0.28           2
# 3                    13                 24             0.39           4
# 5                    18                 38             0.08           4
# 6                    17                 34             0.20           3
# 7                    11                 23             0.04           3
# 8                    16                 37             0.00           4
# 9                     8                 20             0.01           3
# 15                   11                 29             0.12           3
# 16                   12                 29             0.16           3
# 21                    9                 20             0.01           5
# 22                    8                 28             0.04           2
# 24                    8                 38             0.08           4
# 25                   12                 24             0.20           4
# 26                   14                 29             0.08           3
# 30                    8                 31             0.28           5
# 31                   15                 44             0.00           2
# 32                   15                 29             0.00           2
# 34                   13                 33             0.02           4
# 35                   21                 41             0.08           4
# 36                   16                 25             0.28           4
# 37                   12                 36             0.02           4
# 38                   20                 43             0.08           3
# 39                   21                 41             0.00           3
# 41                   12                 36             0.08           3
# 42                   16                 47             0.31           3
# 43                   17                 30             0.00           2
# 44                   15                 56             0.35           5
# 45                   29                 53             0.02           4
# ..                  ...                ...              ...         ...
# 281                  13                 33             0.08           2
# 282                   9                 26             0.12           2
# 284                   4                 23             0.08           2
# 288                   6                 21             0.01           2
# 289                   8                 26             0.02           2
# 291                  13                 29             0.00           3
# 293                  17                 43             0.12           3
# 298                  11                 25             0.00           5
# 299                  10                 25             0.00           3
# 300                   7                 23             0.00           3
# 303                   5                 30             0.00           1
# 304                  11                 30             0.01           3
# 305                  14                 31             0.47           4
# 306                   9                 21             0.20           3
# 310                  14                 26             0.20           4
# 311                  11                 32             0.08           3
# 312                   4                 20             0.00           2
# 336                  10                 23             0.02           4
# 342                   9                 32             0.01           5
# 345                  16                 34             0.04           3
# 347                   9                 28             0.01           3
# 350                  13                 34             0.01           5
# 351                  18                 37             0.00           6
# 353                  12                 28             0.00           3
# 354                  14                 29             0.00           6
# 355                  20                 34             0.00           5
# 356                  20                 38             0.00           4
# 357                  16                 28             0.01           5
# 360                  16                 38             0.00           4
# 364                   5                 23             0.01           4
#
#                 Events  WindDirDegrees
# 0                 Rain             186
# 1                 Rain             214
# 2    Rain-Thunderstorm             219
# 3                 Rain             211
# 5                 Rain             219
# 6                 Rain             219
# 7                 Rain             197
# 8                 Rain             247
# 9                 Rain             216
# 15                Rain             188
# 16                Rain             192
# 21                Rain             221
# 22                Rain             265
# 24            Fog-Rain             249
# 25                Rain             232
# 26                Rain             228
# 30            Fog-Rain             173
# 31                Rain             220
# 32                                 216
# 34                Rain             176
# 35                Rain             192
# 36                Rain             190
# 37                Rain             230
# 38                Rain             208
# 39                Rain             228
# 41                Rain             222
# 42   Rain-Thunderstorm             211
# 43                                 236
# 44                Rain             180
# 45                Rain             237
# ..                 ...             ...
# 281  Rain-Thunderstorm             209
# 282               Rain             207
# 284           Fog-Rain              53
# 288               Rain             214
# 289               Rain             188
# 291               Rain             225
# 293               Rain             268
# 298                                217
# 299                                192
# 300           Fog-Rain             181
# 303                                170
# 304               Rain             211
# 305               Rain             207
# 306               Rain             208
# 310               Rain             207
# 311               Rain             192
# 312                Fog             212
# 336               Rain              17
# 342               Rain             224
# 345               Rain             253
# 347               Rain             215
# 350               Rain             252
# 351                                245
# 353               Rain             251
# 354               Rain             237
# 355               Rain             240
# 356               Rain             238
# 357               Rain             262
# 360               Rain             330
# 364                Fog             201
#
# [128 rows x 23 columns]

# %% [markdown]
# Note that the table above has fewer than 251 of the original 365 rows, so there must be further null values besides the 114 missing events.

# %% [markdown]
# ### Changing the value type of a column

# %% [markdown]
# The type of every column in a dataframe can be determined by looking at the dataframe's `dtypes` attribute, like this:

# %%
london.dtypes
# Out:
# GMT                           object
# Max TemperatureF               int64
# Mean TemperatureF              int64
# Min TemperatureF               int64
# Max Dew PointF                 int64
# MeanDew PointF                 int64
# Min DewpointF                  int64
# Max Humidity                   int64
# Mean Humidity                  int64
# Min Humidity                   int64
# Max Sea Level PressureIn     float64
# Mean Sea Level PressureIn    float64
# Min Sea Level PressureIn     float64
# Max VisibilityMiles            int64
# Mean VisibilityMiles           int64
# Min VisibilityMiles            int64
# Max Wind SpeedMPH              int64
# Mean Wind SpeedMPH             int64
# Max Gust SpeedMPH            float64
# PrecipitationIn              float64
# CloudCover                   float64
# Events                        object
# WindDirDegrees                 int64
# dtype: object

# %% [markdown]
# The type of all the values in a column can be changed using the <code>astype()</code> method. The following code will change the values in the <code>'WindDirDegrees'</code> column from strings (`object`) to integers (<code>int64</code>).

# %%
london['WindDirDegrees'] = london['WindDirDegrees'].astype('int64')

# %% [markdown]
# The function `to_datetime()` is needed to change the values in the `'GMT'` column from strings (`object`) to dates (`datetime64`):

# %%
london['GMT'] = to_datetime(london['GMT'])
london.dtypes
# Out:
# GMT                          datetime64[ns]
# Max TemperatureF                      int64
# Mean TemperatureF                     int64
# Min TemperatureF                      int64
# Max Dew PointF                        int64
# MeanDew PointF                        int64
# Min DewpointF                         int64
# Max Humidity                          int64
# Mean Humidity                         int64
# Min Humidity                          int64
# Max Sea Level PressureIn            float64
# Mean Sea Level PressureIn           float64
# Min Sea Level PressureIn            float64
# Max VisibilityMiles                   int64
# Mean VisibilityMiles                  int64
# Min VisibilityMiles                   int64
# Max Wind SpeedMPH                     int64
# Mean Wind SpeedMPH                    int64
# Max Gust SpeedMPH                   float64
# PrecipitationIn                     float64
# CloudCover                          float64
# Events                               object
# WindDirDegrees                        int64
# dtype: object

# %% [markdown]
# Values of type `datetime64` can be created using the `datetime()` function where the first integer argument is the year, the second the month and the third the day.
# The code below will get and display the row in the dataframe whose `'GMT'` value is 4th June 2014.

# %%
london[london['GMT'] == datetime(2014, 6, 4)]
# Out:
#            GMT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 154 2014-06-04                58                 52                46
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 154              52              48             37            94
#
#      Mean Humidity  Min Humidity       ...        Max VisibilityMiles  \
# 154             78            47       ...                         19
#
#      Mean VisibilityMiles  Min VisibilityMiles  Max Wind SpeedMPH  \
# 154                     7                    4                 29
#
#      Mean Wind SpeedMPH  Max Gust SpeedMPH  PrecipitationIn  CloudCover  \
# 154                   8                 40             0.08           4
#
#                 Events  WindDirDegrees
# 154  Rain-Thunderstorm             230
#
# [1 rows x 23 columns]

# %% [markdown]
# Queries such as 'Return all the rows where the date is between 8 December and 12 December' can be made:

# %%
dates = london['GMT']
start = datetime(2014, 12, 8)
end = datetime(2014, 12, 12)
london[(dates >= start) & (dates <= end)]
# Out:
#            GMT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 341 2014-12-08                45                 40                33
# 342 2014-12-09                53                 42                31
# 343 2014-12-10                48                 45                42
# 344 2014-12-11                50                 46                41
# 345 2014-12-12                48                 42                35
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 341              36              33             31            93
# 342              51              38             30           100
# 343              51              38             33            90
# 344              43              38             35            82
# 345              48              40             31            94
#
#      Mean Humidity  Min Humidity       ...        Max VisibilityMiles  \
# 341             76            51       ...                         19
# 342             86            64       ...                         19
# 343             70            44       ...                         19
# 344             72            51       ...                         19
# 345             79            59       ...                         19
#
#      Mean VisibilityMiles  Min VisibilityMiles  Max Wind SpeedMPH  \
# 341                    10                    6                 14
# 342                     9                    2                 23
# 343                    11                    2                 25
# 344                     9                    6                 25
# 345                     7                    2                 25
#
#      Mean Wind SpeedMPH  Max Gust SpeedMPH  PrecipitationIn  CloudCover  \
# 341                   8                NaN             0.00           2
# 342                   9                 32             0.01           5
# 343                  17                NaN             0.00           2
# 344                  19                NaN             0.01           2
# 345                  16                 34             0.04           3
#
#      Events  WindDirDegrees
# 341    Rain             270
# 342    Rain             224
# 343    Rain             246
# 344    Rain             246
# 345    Rain             253
#
# [5 rows x 23 columns]

# %% [markdown]
# ###Tasks
#
# Now that the wind direction is given by a number, write code to select all days that had a northerly wind. Hint: select the rows where the direction is greater or equal than 350 **or** smaller or equal than 10, as the compass rose shows.

# %%
windDir = london['WindDirDegrees']
london[(windDir >= 350) | (windDir <= 10)]
# Out:
#            GMT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 84  2014-03-26                49                 42                36
# 90  2014-04-01                66                 55                44
# 100 2014-04-11                60                 54                49
# 110 2014-04-21                66                 54                41
# 174 2014-06-24                76                 66                56
# 179 2014-06-29                67                 60                54
# 190 2014-07-10                71                 64                58
# 208 2014-07-28                74                 66                57
# 249 2014-09-07                70                 63                55
# 250 2014-09-08                72                 61                50
# 335 2014-12-02                46                 44                42
# 361 2014-12-28                43                 36                28
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 84               39              35             31           100
# 90               52              48             43           100
# 100              41              39             35            71
# 110              52              46             40           100
# 174              59              54             48            94
# 179              52              48             41            88
# 190              55              52             48            82
# 208              61              54             48            94
# 249              57              53             47            94
# 250              55              49             45            94
# 335              45              40             35           100
# 361              34              29             27           100
#
#      Mean Humidity  Min Humidity       ...        Max VisibilityMiles  \
# 84              80            39       ...                         17
# 90              80            39       ...                         12
# 100             53            28       ...                         19
# 110             78            31       ...                         16
# 174             66            27       ...                         19
# 179             65            31       ...                         19
# 190             64            44       ...                         19
# 208             66            33       ...                         16
# 249             71            41       ...                         14
# 250             64            28       ...                         17
# 335             80            62       ...                         19
# 361             76            45       ...                         19
#
#      Mean VisibilityMiles  Min VisibilityMiles  Max Wind SpeedMPH  \
# 84                      6                    1                 16
# 90                      4                    0                 10
# 100                    11                    6                  8
# 110                     5                    0                  9
# 174                     7                    0                 14
# 179                    10                    6                 12
# 190                    12                    6                 10
# 208                     8                    1                 13
# 249                     6                    2                  7
# 250                     8                    3                  7
# 335                     7                    1                 17
# 361                    10                    5                 10
#
#      Mean Wind SpeedMPH  Max Gust SpeedMPH  PrecipitationIn  CloudCover  \
# 84                    6                NaN             0.08           4
# 90                    3                NaN             0.00           4
# 100                   5                NaN             0.00           1
# 110                   4                NaN             0.39           3
# 174                   5                 23             0.00           3
# 179                   6                NaN             0.00           2
# 190                   9                NaN             0.00           3
# 208                   6                NaN             0.67           2
# 249                   4                NaN             0.00           4
# 250                   4                NaN             0.00           1
# 335                   8                NaN             0.04           5
# 361                   7                NaN             0.00           1
#
#                     Events  WindDirDegrees
# 84                Fog-Rain               3
# 90                Fog-Rain               6
# 100                                    351
# 110  Fog-Rain-Thunderstorm             356
# 174                    Fog             350
# 179                   Rain               9
# 190                                      1
# 208      Rain-Thunderstorm               3
# 249                                    354
# 250                                    351
# 335                   Rain             359
# 361                                      5
#
# [12 rows x 23 columns]

# %% [markdown]
# In the code cell below, write code to get and display all the rows in the dataframe that are beween 1 April 2014 and
# 11 April 2014.

# %%
dates = london['GMT']
start = datetime(2014, 4, 1)
end = datetime(2014, 4, 11)
london[(dates >= start) & (dates <= end)]
# Out:
#            GMT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 90  2014-04-01                66                 55                44
# 91  2014-04-02                65                 58                51
# 92  2014-04-03                64                 58                51
# 93  2014-04-04                59                 54                48
# 94  2014-04-05                58                 50                42
# 95  2014-04-06                60                 57                54
# 96  2014-04-07                57                 52                46
# 97  2014-04-08                57                 49                41
# 98  2014-04-09                62                 50                39
# 99  2014-04-10                61                 52                43
# 100 2014-04-11                60                 54                49
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 90               52              48             43           100
# 91               52              49             45            88
# 92               52              49             48            88
# 93               50              46             42            88
# 94               52              47             41           100
# 95               54              53             52            94
# 96               54              51             43            94
# 97               43              38             31            87
# 98               45              42             37            93
# 99               43              41             37            93
# 100              41              39             35            71
#
#      Mean Humidity  Min Humidity       ...        Max VisibilityMiles  \
# 90              80            39       ...                         12
# 91              71            48       ...                          6
# 92              75            52       ...                         13
# 93              71            46       ...                         19
# 94              83            56       ...                         19
# 95              88            67       ...                         19
# 96              87            76       ...                         19
# 97              64            26       ...                         19
# 98              68            38       ...                         19
# 99              62            31       ...                         19
# 100             53            28       ...                         19
#
#      Mean VisibilityMiles  Min VisibilityMiles  Max Wind SpeedMPH  \
# 90                      4                    0                 10
# 91                      5                    3                 14
# 92                      4                    2                 16
# 93                      7                    1                 15
# 94                      7                    0                 16
# 95                      8                    3                 22
# 96                      9                    3                 18
# 97                      9                    6                 24
# 98                      9                    4                 14
# 99                      9                    6                 12
# 100                    11                    6                  8
#
#      Mean Wind SpeedMPH  Max Gust SpeedMPH  PrecipitationIn  CloudCover  \
# 90                    3                NaN             0.00           4
# 91                    8                NaN             0.00           1
# 92                    7                NaN             0.00           5
# 93                    9                NaN             0.00           5
# 94                    8                 31             0.00           5
# 95                   13                 30             0.08           6
# 96                   14                 26             0.08           5
# 97                   14                NaN             0.00           2
# 98                    8                NaN             0.00           2
# 99                    6                NaN             0.00           3
# 100                   5                NaN             0.00           1
#
#        Events  WindDirDegrees
# 90   Fog-Rain               6
# 91       Rain              85
# 92                         96
# 93                        253
# 94   Fog-Rain             197
# 95       Rain             213
# 96       Rain             209
# 97       Rain             269
# 98                        261
# 99                        278
# 100                       351
#
# [11 rows x 23 columns]

# %% [markdown]
# In the cell below, write two lines of code to display the first five rows that have a missing value in the `'Max Gust SpeedKm/h'` column. Hint: first select the missing value rows and store them in a new dataframe, then display the first five rows of the new dataframe.

# %%
maxGust = london[london['Max Gust SpeedMPH'].isnull()]
maxGust.head(5)
# Out:
#           GMT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 4  2014-01-05                54                 44                33
# 10 2014-01-11                48                 40                32
# 11 2014-01-12                50                 39                28
# 12 2014-01-13                49                 45                41
# 13 2014-01-14                45                 39                33
#
#     Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 4               52              40             31           100
# 10              45              38             30           100
# 11              48              37             28           100
# 12              46              40             37            93
# 13              41              36             32           100
#
#     Mean Humidity  Min Humidity       ...        Max VisibilityMiles  \
# 4              88            77       ...                         19
# 10             80            51       ...                         19
# 11             91            79       ...                         19
# 12             85            71       ...                         19
# 13             82            55       ...                         19
#
#     Mean VisibilityMiles  Min VisibilityMiles  Max Wind SpeedMPH  \
# 4                      9                    3                 22
# 10                     7                    4                 15
# 11                     6                    0                 20
# 12                    10                    3                 21
# 13                     9                    6                 13
#
#     Mean Wind SpeedMPH  Max Gust SpeedMPH  PrecipitationIn  CloudCover  \
# 4                   10                NaN             0.01           5
# 10                   9                NaN             0.00           4
# 11                   6                NaN             0.02           6
# 12                  12                NaN             0.20           2
# 13                   8                NaN             0.01           3
#
#       Events  WindDirDegrees
# 4       Rain             199
# 10      Rain             259
# 11  Fog-Rain             126
# 12      Rain             205
# 13      Rain             242
#
# [5 rows x 23 columns]

# %% [markdown]
# **Now go back to the Exercise 4 step in FutureLearn to discuss and mark it complete.**

# %% [markdown]
# ##Exercise 5: Every picture tells a story
#
# The following line of code tells Jupyter to display inside this notebook any graph that is created.

# %%
# %matplotlib inline

# %% [markdown]
# The `plot()` method can make a graph of the values in a column. Gridlines are turned on by the `grid` argument.

# %%
london['Max Wind SpeedMPH'].plot(grid=True)

# %% [markdown]
# The graph can be made bigger by giving the method a `figsize=(x,y)` argument where `x` and `y` are integers that determine the length of the x-axis and y-axis.

# %%
london['Max Wind SpeedMPH'].plot(grid=True, figsize=(10,5))

# %% [markdown]
# Multiple lines can be plotted by selecting multiple columns.

# %%
london[['Max Wind SpeedMPH', 'Mean Wind SpeedMPH']].plot(grid=True, figsize=(10,5))

# %% [markdown]
# ### Task
#
# In the cell below, write code to plot the minimum, mean, and maximum temperature during 2014 in London.

# %%
london[['Max TemperatureF', 'Mean TemperatureF', 'Min TemperatureF']].plot(grid=True, figsize=(10,5))

# %% [markdown]
# **Now go back to the Exercise 5 step in FutureLearn to discuss and mark it complete.**

# %% [markdown]
# ##Exercise 6: Changing a dataframe's index
# Changing the dataframe's index from the default to `datetime64` values is done by assigning to the dataframe's `index` attribute the contents of the `'GMT`' column, like this:

# %%
london.index = london['GMT']
london.head(2)
# Out:
#                   GMT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# GMT
# 2014-01-01 2014-01-01                52                 47                42
# 2014-01-02 2014-01-02                52                 48                43
#
#             Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# GMT
# 2014-01-01              48              44             39            94
# 2014-01-02              48              43             40            94
#
#             Mean Humidity  Min Humidity       ...        Max VisibilityMiles  \
# GMT                                           ...
# 2014-01-01             86            73       ...                         19
# 2014-01-02             81            60       ...                         19
#
#             Mean VisibilityMiles  Min VisibilityMiles  Max Wind SpeedMPH  \
# GMT
# 2014-01-01                     7                    1                 25
# 2014-01-02                    10                    3                 20
#
#             Mean Wind SpeedMPH  Max Gust SpeedMPH  PrecipitationIn  \
# GMT
# 2014-01-01                  16                 41             0.39
# 2014-01-02                  13                 31             0.04
#
#             CloudCover  Events  WindDirDegrees
# GMT
# 2014-01-01           4    Rain             186
# 2014-01-02           2    Rain             214
#
# [2 rows x 23 columns]

# %% [markdown]
# The `irow()` method can still be used to get and display rows, but now you can now also use the `datetime64` index to get a row using the dataframe's `ix` (index) property, like this:

# %%
london.ix[datetime(2014, 1, 1)]
# Out:
# GMT                          2014-01-01 00:00:00
# Max TemperatureF                              52
# Mean TemperatureF                             47
# Min TemperatureF                              42
# Max Dew PointF                                48
# MeanDew PointF                                44
# Min DewpointF                                 39
# Max Humidity                                  94
# Mean Humidity                                 86
# Min Humidity                                  73
# Max Sea Level PressureIn                    29.6
# Mean Sea Level PressureIn                  29.32
# Min Sea Level PressureIn                   29.06
# Max VisibilityMiles                           19
# Mean VisibilityMiles                           7
# Min VisibilityMiles                            1
# Max Wind SpeedMPH                             25
# Mean Wind SpeedMPH                            16
# Max Gust SpeedMPH                             41
# PrecipitationIn                             0.39
# CloudCover                                     4
# Events                                      Rain
# WindDirDegrees                               186
# Name: 2014-01-01 00:00:00, dtype: object

# %% [markdown]
# A query such as *'Return all the rows where the date is between December 8th and December 12th'* can now be done  succinctly like this:

# %%
london.ix[datetime(2014,12,8) : datetime(2014,12,12)]

#The meaning of the above code is get the rows beween and including 
#the indices datetime(2014,12,8) and datetime(2014,12,12)
# Out:
#                   GMT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# GMT
# 2014-12-08 2014-12-08                45                 40                33
# 2014-12-09 2014-12-09                53                 42                31
# 2014-12-10 2014-12-10                48                 45                42
# 2014-12-11 2014-12-11                50                 46                41
# 2014-12-12 2014-12-12                48                 42                35
#
#             Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# GMT
# 2014-12-08              36              33             31            93
# 2014-12-09              51              38             30           100
# 2014-12-10              51              38             33            90
# 2014-12-11              43              38             35            82
# 2014-12-12              48              40             31            94
#
#             Mean Humidity  Min Humidity       ...        Max VisibilityMiles  \
# GMT                                           ...
# 2014-12-08             76            51       ...                         19
# 2014-12-09             86            64       ...                         19
# 2014-12-10             70            44       ...                         19
# 2014-12-11             72            51       ...                         19
# 2014-12-12             79            59       ...                         19
#
#             Mean VisibilityMiles  Min VisibilityMiles  Max Wind SpeedMPH  \
# GMT
# 2014-12-08                    10                    6                 14
# 2014-12-09                     9                    2                 23
# 2014-12-10                    11                    2                 25
# 2014-12-11                     9                    6                 25
# 2014-12-12                     7                    2                 25
#
#             Mean Wind SpeedMPH  Max Gust SpeedMPH  PrecipitationIn  \
# GMT
# 2014-12-08                   8                NaN             0.00
# 2014-12-09                   9                 32             0.01
# 2014-12-10                  17                NaN             0.00
# 2014-12-11                  19                NaN             0.01
# 2014-12-12                  16                 34             0.04
#
#             CloudCover  Events  WindDirDegrees
# GMT
# 2014-12-08           2    Rain             270
# 2014-12-09           5    Rain             224
# 2014-12-10           2    Rain             246
# 2014-12-11           2    Rain             246
# 2014-12-12           3    Rain             253
#
# [5 rows x 23 columns]

# %% [markdown]
# Now we have a `datetime64` index, let's plot `'Max Wind SpeedKm/h'` again:

# %%
london['Max Wind SpeedMPH'].plot(grid=True, figsize=(10,5))

# %% [markdown]
# Now it is much clearer that the worst winds were in mid February.
#
# ###Task
# Use the code cell below to plot the values of `'Mean Humidity'` during spring (full months of March, April and May).

# %%
dates = london['GMT']
start = datetime(2014, 3, 1)
end = datetime(2014, 5, 31)
humidity = london[(dates >= start) & (dates <= end)]
humidity['Mean Humidity'].plot(grid=True, figsize=(10,5))

# %% [markdown]
# **Now go back to the Exercise 6 step in FutureLearn to discuss and mark it complete.**
